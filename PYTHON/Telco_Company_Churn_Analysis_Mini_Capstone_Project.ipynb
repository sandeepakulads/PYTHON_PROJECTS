# %% [markdown]
# # **Mini Capstone Project - Telco Company Churn Analysis**

# %% [markdown]
# ### **A fictional telco company that provided home phone and Internet services to 7043 customers in California in Quarter 3 of the fiscal year.**
#
# **Data Description:**
#
# 7043 observations with 33 variables
#
# * CustomerID: A unique ID that identifies each customer. <br>
# * Count: A value used in reporting/dashboarding to sum up the number of customers in a filtered set. <br>
# * Country: The country of the customer’s primary residence. <br>
# * State: The state of the customer’s primary residence. <br>
# * City: The city of the customer’s primary residence. <br>
# * Zip Code: The zip code of the customer’s primary residence. <br>
# * Lat Long: The combined latitude and longitude of the customer’s primary residence. <br>
# * Latitude: The latitude of the customer’s primary residence. <br>
# * Longitude: The longitude of the customer’s primary residence. <br>
# * Gender: The customer’s gender: Male, Female <br>
# * Senior Citizen: Indicates if the customer is 65 or older: Yes, No <br>
# * Partner: Indicate if the customer has a partner: Yes, No <br>
# * Dependents: Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents, grandparents, etc. <br>
# * Tenure Months: Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above. <br>
# * Phone Service: Indicates if the customer subscribes to home phone service with the company: Yes, No <br>
# * Multiple Lines: Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No <br>
# * Internet Service: Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable. <br>
# * Online Security: Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No <br>
# * Online Backup: Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No <br>
# * Device Protection: Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No <br>
# * Tech Support: Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No <br>
# * Streaming TV: Indicates if the customer uses their Internet service to stream television programming from a third party<br>  provider: Yes, No. The company does not charge an additional fee for this service. <br>
# * Streaming Movies: Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service. <br>
# * Contract: Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year. <br>
# * Paperless Billing: Indicates if the customer has chosen paperless billing: Yes, No <br>
# * Payment Method: Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check <br>
# * Monthly Charge: Indicates the customer’s current total monthly charge for all their services from the company. <br>
# * Total Charges: Indicates the customer’s total charges, calculated to the end of the quarter specified above. <br>
# * Churn Label: Yes = the customer left the company this quarter. No = the customer remained with the company. Directly related to Churn Value. <br>
# * Churn Value: 1 = the customer left the company this quarter. 0 = the customer remained with the company. Directly related to Churn Label. <br>
# * Churn Score: A value from 0-100 that is calculated using the predictive tool IBM SPSS Modeler. The model incorporates multiple factors known to cause churn. The higher the score, the more likely the customer will churn. <br>
# * CLTV: Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn. <br>
# * Churn Reason: A customer’s specific reason for leaving the company. Directly related to Churn Category. <br>

# %% [markdown]
# ### **📓 Introduction :**
# This particular dataset contains information of customers from a fictional telco company which provided Phone and Internet services to 7043 customers in California in Quarter 3 of the fiscal year. Company provided Services in various cities of State California in United States. Dataset contains Customer ID along with other details like demographics information i.e., Gender, Senior Citizen, Partner and Dependents and also geographic information includes Country, State, City, Zip Code, Latitude and Longitude. However, it is understood that, there is no data about customer names (first name, middle name and last name) in the dataset.
#
# The dataset contains customer account information which are Tenure Months, Contract, Payment Method, Monthly Charges and Total Charges.
#
# ### **🎯 Aim :**
#
# Aim of this dataset is to predict whether the customers in the company decides to continue or not with services provided by the company after a certain quarter.

# %% [markdown]
# ### **🧰🔧⚙ Importing Necessary Libraries :**

# %%
# importing necessary libraries required to perform operations on dataset
import numpy as np                #importing numpy to perform mathematical operations
import pandas as pd               #importing pandas to perform data analysis    
import seaborn as sns             #importing for making statistical graphics
import matplotlib.pyplot as plt   #data visualization and graphical plotting
import warnings                   # importring warning to avoid future warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### **Please read the file and explain data types statistically as well as how python is reading it. Please let us know if any data type is read wrong.**

# %%
# Reading dataset and assigning dataset to variable 'data'
data = pd.read_excel("/content/Telco_customer_churn.xlsx")
data.T # transpoing data for better viewing of all the existing columns in the dataset
# Out:
#                                            0                      1     \
# CustomerID                           3668-QPYBK             9237-HQITU
# Count                                         1                      1
# Country                           United States          United States
# State                                California             California
# City                                Los Angeles            Los Angeles
# Zip Code                                  90003                  90005
# Lat Long                 33.964131, -118.272783  34.059281, -118.30742
# Latitude                              33.964131              34.059281
# Longitude                           -118.272783             -118.30742
# Gender                                     Male                 Female
# Senior Citizen                               No                     No
# Partner                                      No                     No
# ...

# %% [markdown]
# * As we have transposed the data above, it is showing **33 rows and 7043 columns**, but technically there are **33 columns (features) and 7043 rows (observations)** in it.

# %% [markdown]
# |Column|Statistics Data Type|Python Data Type|
# |-|-|-|
# |CustomerID|Nominal|String|
# |Count|Discrete|Integer|
# |Country|Nominal|String|
# |State|Nominal|String|
# |City|Nominal|String|
# |Zip Code|Discrete|Integer|
# |Lat Long|Continuous|String|
# |Latitude|Continuous|Float|
# |Longitude|Continuous|Float|
# |Gender|Binary|String|
# |Senior Citizen|Binary|String|
# |Partner|Binary|String|
# |Dependents|Binary|String|
# |Tenure Months|Discrete|Integer|
# |Phone Service|Binary|String|
# |Multiple Lines|Nominal|String|
# |Internet Service|Nominal|String|
# |Online Security|Nominal|String|
# |Online Backup|Nominal|String|
# |Device Protection|Nominal|String|
# |Tech Support|Nominal|String|
# |Streaming TV|Nominal|String|
# |Streaming Movies|Nominal|String|
# |Contract|Continuous|String|
# |Paperless Billing|Binary|String|
# |Payment Method|Nominal|String|
# |Monthly Charges|Continuous|Float|
# |Total Chrages|Continuous|Float|
# |Churn Label|Binary|String|
# |Churn Value|Binary|Integer|
# |Churn Score|Ordinal|Integer|
# |CLTV|Ordinal|Integer|
# |Churn Reason|Nominal|String|

# %%
# %%html
# <style>
# table{float:left}
# </style>
# Out:
# <style>
# table{float:left}
# </style>

# %% [markdown]
# **Checking for Duplicate Records :**

# %%
data.duplicated().sum() # checking whether any duplicate entries are present in the dataset
# Out:
# 0

# %% [markdown]
# * The provided dataset does not have any duplicate entries in it.

# %%
data.info() # getting information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# * Dataset contains 33 columns (features) and 7043 rows (observations / entries) in it. Python reading columns like Count, Zip Code, Tenure Months, Churn Value, Churn Score, CLTV  as 'float64' type and Total Charges as object type. Those columns which are 'float64' types be converted to 'int' type and Total charges from 'object' type to 'float64' type.

# %% [markdown]
# **Converting Data Types :**

# %%
# converting variable data type from 'float64' to 'int64' using astype() function which is used to cast a data type to required data type
data = data.astype({"Count":'int64', "Zip Code":'int64', "Tenure Months":'int64',
                    "Churn Value":'int64', "Churn Score":'int64', "CLTV":'int64'})
# converting variable data type from 'object' to 'float64' using to_numeric() function
data['Total Charges'] = pd.to_numeric(data['Total Charges'], errors='coerce')

# %% [markdown]
# **Checking Data Types :**

# %%
# printing variable data types once again
data.dtypes
# Out:
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges        float64
# Churn Label           object
# Churn Value            int64
# Churn Score            int64
# CLTV                   int64
# ...

# %% [markdown]
# * Now python is reading Count, Zip Code, Tenure Months, Churn Value, Churn Score, CLTV columns as 'int64' type and Total Charges as 'float64'.

# %% [markdown]
# **Checking Number of Unique Values in Each Column :**

# %%
data.nunique() # finding number of unique entries in each of the column
# Out:
# CustomerID           7043
# Count                   1
# Country                 1
# State                   1
# City                 1129
# Zip Code             1652
# Lat Long             1652
# Latitude             1652
# Longitude            1651
# Gender                  2
# Senior Citizen          2
# Partner                 2
# Dependents              2
# Tenure Months          73
# Phone Service           2
# Multiple Lines          3
# Internet Service        3
# Online Security         3
# Online Backup           3
# Device Protection       3
# Tech Support            3
# Streaming TV            3
# Streaming Movies        3
# Contract                3
# Paperless Billing       2
# Payment Method          4
# Monthly Charges      1585
# Total Charges        6530
# Churn Label             2
# Churn Value             2
# Churn Score            85
# CLTV                 3438
# Churn Reason           20
# dtype: int64

# %% [markdown]
# * There are certain columns that have only one unique value in it. Count, Country and State are having only one unique value. And also there are separate columns avaiable for Latitude and Longitud as well. Thus, no necessity of Lat Long Column in the dataset.

# %% [markdown]
# **Dropping Unwanted Columns :**

# %%
data = pd.DataFrame(data)
data.drop(columns = ['Count', 'Country', 'State', 'Lat Long'], inplace=True)
data
# Out:
#       CustomerID          City  Zip Code   Latitude   Longitude  Gender  \
# 0     3668-QPYBK   Los Angeles     90003  33.964131 -118.272783    Male
# 1     9237-HQITU   Los Angeles     90005  34.059281 -118.307420  Female
# 2     9305-CDSKC   Los Angeles     90006  34.048013 -118.293953  Female
# 3     7892-POOKP   Los Angeles     90010  34.062125 -118.315709  Female
# 4     0280-XJGEX   Los Angeles     90015  34.039224 -118.266293    Male
# ...          ...           ...       ...        ...         ...     ...
# 7038  2569-WGERO       Landers     92285  34.341737 -116.539416  Female
# 7039  6840-RESVB      Adelanto     92301  34.667815 -117.536183    Male
# 7040  2234-XADUH         Amboy     92304  34.559882 -115.637164  Female
# 7041  4801-JZAZL  Angelus Oaks     92305  34.167800 -116.864330  Female
# 7042  3186-AJIEK  Apple Valley     92308  34.424926 -117.184503    Male
#
#      Senior Citizen Partner Dependents  Tenure Months  ...        Contract  \
# ...

# %% [markdown]
# ### **Please apply appropriate statistical measures using python based on data types.**

# %% [markdown]
# * There are certain numerical columns namely Monthly Charges, Total Charges, Churn Score and CLTV on which we can apply statistical measures.

# %% [markdown]
# **Statistical Measures of Monthly Charges:**

# %%
print("STATISTICAL MEASURES OF MONTHLY CHARGES :")
print('\nMean : ', round(data['Monthly Charges'].mean(),2))
print('\nMedian: ', data['Monthly Charges'].median())
print('\nMode :', data['Monthly Charges'].mode())
print('\nMinimum :', data['Monthly Charges'].min())
print('\nMaximum: ', data['Monthly Charges'].max())


monthly_charges_q1, monthly_charges_q3 = np.percentile(data['Monthly Charges'], [25, 75])
monthly_charges_IQR = monthly_charges_q3 - monthly_charges_q1  
print('\nIQR : ', round(monthly_charges_IQR), 2)

monthly_charges_var = data['Monthly Charges'].var()
print('\nVariance : ', round(monthly_charges_var,2))

monthly_charges_std = data['Monthly Charges'].std()
print('\nStandard Deviation : ', round(monthly_charges_std,2))
# Out:
# STATISTICAL MEASURES OF MONTHLY CHARGES :
#
# Mean :  64.76
#
# Median:  70.35
#
# Mode : 0    20.05
# dtype: float64
#
# Minimum : 18.25
#
# Maximum:  118.75
#
# IQR :  54 2
#
# Variance :  905.41
#
# Standard Deviation :  30.09

# %% [markdown]
# **Statistical Measures of Total Charges:**

# %%
print("STATISTICAL MEASURES OF TOTAL CHARGES :")
print('\nMean : ', round(data['Total Charges'].mean(),2))
print('\nMedian: ', round(data['Total Charges'].median(),2))
print('\nMode :', data['Total Charges'].mode())
print('\nMinimum :', data['Total Charges'].min())
print('\nMaximum: ', data['Total Charges'].max())


total_charges_q1, total_charges_q3 = np.percentile(data['Total Charges'], [25, 75])
total_charges_IQR = total_charges_q3 - total_charges_q1  
print('\nIQR : ', total_charges_IQR)

total_charges_var = data['Total Charges'].var()
print('\nVariance : ', round(total_charges_var,2))

total_charges_std = data['Total Charges'].std()
print('\nStandard Deviation : ', round(total_charges_std,2))
# Out:
# STATISTICAL MEASURES OF TOTAL CHARGES :
#
# Mean :  2283.3
#
# Median:  1397.48
#
# Mode : 0    20.2
# dtype: float64
#
# Minimum : 18.8
#
# Maximum:  8684.8
#
# IQR :  nan
#
# Variance :  5138252.41
#
# Standard Deviation :  2266.77

# %% [markdown]
# **Statistical Measures of Churn Score:**

# %%
print("STATISTICAL MEASURES OF CHURN SCORE :")
print('\nMean : ', round(data['Churn Score'].mean(),2))
print('\nMedian: ', round(data['Churn Score'].median(),2))
print('\nMode :', data['Churn Score'].mode())
print('\nMinimum :', data['Churn Score'].min())
print('\nMaximum: ', data['Churn Score'].max())


churn_score_q1, churn_score_q3 = np.percentile(data['Churn Score'], [25, 75])
churn_score_IQR = churn_score_q3 - churn_score_q1  
print('\nIQR : ', churn_score_IQR)

churn_score_var = data['Churn Score'].var()
print('\nVariance : ', round(churn_score_var,2))

churn_score_std = data['Churn Score'].std()
print('\nStandard Deviation : ', round(churn_score_std,2))
# Out:
# STATISTICAL MEASURES OF CHURN SCORE :
#
# Mean :  58.7
#
# Median:  61.0
#
# Mode : 0    80
# dtype: int64
#
# Minimum : 5
#
# Maximum:  100
#
# IQR :  35.0
#
# Variance :  463.33
#
# Standard Deviation :  21.53

# %% [markdown]
# **Statistical Measures of CLTV:**

# %%
print("STATISTICAL MEASURES OF CLTV :")
print('\nMean : ', round(data['CLTV'].mean(),2))
print('\nMedian: ', round(data['CLTV'].median(),2))
print('\nMode :', data['CLTV'].mode())
print('\nMinimum :', data['CLTV'].min())
print('\nMaximum: ', data['CLTV'].max())


cltv_q1, cltv_q3 = np.percentile(data['CLTV'], [25, 75])
cltv_IQR = cltv_q3 - cltv_q1  
print('\nIQR : ', cltv_IQR)

cltv_var = data['CLTV'].var()
print('\nVariance : ', round(cltv_var,2))

cltv_std = data['CLTV'].std()
print('\nStandard Deviation : ', round(cltv_std,2))
# Out:
# STATISTICAL MEASURES OF CLTV :
#
# Mean :  4400.3
#
# Median:  4527.0
#
# Mode : 0    5546
# dtype: int64
#
# Minimum : 2003
#
# Maximum:  6500
#
# IQR :  1911.5
#
# Variance :  1399624.22
#
# Standard Deviation :  1183.06

# %% [markdown]
# **Statistical Measures of Tenure Months:**

# %%
print("STATISTICAL MEASURES OF TENURE MONTHS :")
print('\nMean : ', round(data['Tenure Months'].mean(),2))
print('\nMedian: ', round(data['Tenure Months'].median(),2))
print('\nMode :', data['Tenure Months'].mode())
print('\nMinimum :', data['Tenure Months'].min())
print('\nMaximum: ', data['Tenure Months'].max())


tenure_months_q1, tenure_months_q3 = np.percentile(data['Tenure Months'], [25, 75])
tenure_months_IQR = tenure_months_q3 - tenure_months_q1  
print('\nIQR : ', tenure_months_IQR)

tenure_months_var = data['Tenure Months'].var()
print('\nVariance : ', round(tenure_months_var,2))

tenure_months_std = data['Tenure Months'].std()
print('\nStandard Deviation : ', round(tenure_months_std,2))
# Out:
# STATISTICAL MEASURES OF TENURE MONTHS :
#
# Mean :  32.37
#
# Median:  29.0
#
# Mode : 0    1
# dtype: int64
#
# Minimum : 0
#
# Maximum:  72
#
# IQR :  46.0
#
# Variance :  603.17
#
# Standard Deviation :  24.56

# %% [markdown]
# ### **What is the percentage of females and senior citizens in this data set? Please create appropriate plots and explain the plots.**

# %% [markdown]
# * Here the appropriate plot will be Pie Chart since we were asked to find out the percentage of catergorical columns and Pie charts deals in percentage parameter and will be best suitable and an appropriate plot.
# * First we are finding the size of the each distinct entry in the Gender Column using groupby function.

# %%
# groupby() function used to split the data into groups in Gender Column
# size() function gives size of each distinct group
print(data.groupby('Gender').size()) 

# grouped data used to plot pie chart with 'Female' and 'Male' labels and autopct '%.2f%%' used to round off to 2 values after decimal
plt.pie(data.groupby('Gender').size(), labels = ['Female', 'Male'], autopct='%.2f%%')

# creating legend includes title and placing at center right
plt.legend(title = '%Male Vs %Female', loc = 'center right', bbox_to_anchor=(1,0.5), bbox_transform=plt.gcf().transFigure)
plt.show
# Out:
# Gender
# Female    3488
# Male      3555
# dtype: int64
# <function matplotlib.pyplot.show>

# %% [markdown]
# * Percentage of Females Users is **49.52%** which is only just 0.96% less than the Male Users (50.48%).

# %%
# groupby() function used to split the data into groups in Senior Citizen Column
# size() function gives size of each distinct group
print(data.groupby('Senior Citizen').size())

# grouped data used to plot pie chart with 'Female' and 'Male' labels and autopct '%.2f%%' used to round off to 2 values after decimal
plt.pie(data.groupby('Senior Citizen').size(), labels = ['Non Senior Citizen', 'Senior Citizen'], autopct='%.2f%%')

# creating legend includes title
plt.legend(title = '% Senior Citizens Vs % Non Senior Citizens', loc = 8, bbox_to_anchor=(1,0.5), bbox_transform=plt.gcf().transFigure)
plt.show
# Out:
# Senior Citizen
# No     5901
# Yes    1142
# dtype: int64
# <function matplotlib.pyplot.show>

# %% [markdown]
# * Percentage of Senior Citizen Users is just only 16.21% which far less than Non Senior Citizen Users (83.79%)

# %% [markdown]
# ### **Please create an appropriate plot to examine the distribution of the tenure month column and explain the distribution. Based on distribution, perform appropriate statistical measures. Please also explain if the variable is symmetric or skewed. Please calculate it. Explain everything as asked.**

# %% [markdown]
# * To examine the distribution of variable, distplot or histplot are appropriate plots

# %%
plt.figure(figsize = (10,6))
# ploltting distplot of Tenure Months in blue color with 15 bins in it
sns.histplot(data['Tenure Months'], kde=True, color='b', bins=15)                       # plotting the histogram plot with distribution.
plt.title("Distribution of Tenure Months", fontsize=20)                                 # giving title to each graph.
plt.axvline(x=data["Tenure Months"].mean(),ls='--',lw=2.5,color='red',label="mean")     # fixing 'mean' line and its characteristics.
plt.axvline(x=data["Tenure Months"].median(),color='green',label="median")              # fixing 'median' line and its characteristics.

# %%
# finding skewness of the column Tenure Months
print('\nSkewness of Tenure Months : ', round(data['Tenure Months'].skew(),2))
# Out:
# Skewness of Tenure Months :  0.24

# %% [markdown]
# * A value between -0.5 and 0.5 indicates that the distribution is fairly symmetrical. Therefore, Tenure Months variable which is having a skewness of 0.239 in dataset is fairly symmetrical. If it is symmetrical then, Mean is most common measure of central tendency.
#
# * But in the above figure the plot shows two distinct peak which may be an indication of bimodal distribution.

# %%
print('\nMean of Tenure Months : ', round(data['Tenure Months'].mean(),2))

print('\nMedian of Tenure Months : ', round(data['Tenure Months'].median(),2))
# Out:
# Mean of Tenure Months :  32.37
#
# Median of Tenure Months :  29.0

# %%
tenure_months_std = data['Tenure Months'].std()
print('\nStandard Deviation of Tenure Months : ', round(tenure_months_std,2))
# Out:
# Standard Deviation of Tenure Months :  24.56

# %% [markdown]
# ### **Please convert all binary columns into 0 and 1 using appropriate programming constructs, not one by one.**

# %%
data.nunique()
# Out:
# CustomerID           7043
# City                 1129
# Zip Code             1652
# Latitude             1652
# Longitude            1651
# Gender                  2
# Senior Citizen          2
# Partner                 2
# Dependents              2
# Tenure Months          73
# Phone Service           2
# Multiple Lines          3
# Internet Service        3
# Online Security         3
# Online Backup           3
# Device Protection       3
# Tech Support            3
# Streaming TV            3
# Streaming Movies        3
# Contract                3
# Paperless Billing       2
# Payment Method          4
# Monthly Charges      1585
# Total Charges        6530
# Churn Label             2
# Churn Value             2
# Churn Score            85
# CLTV                 3438
# Churn Reason           20
# dtype: int64

# %%
for i in data.columns:
    print(f'{i} : {data[i].unique()}\n')
# Out:
# CustomerID : ['3668-QPYBK' '9237-HQITU' '9305-CDSKC' ... '2234-XADUH' '4801-JZAZL'
#  '3186-AJIEK']
#
# City : ['Los Angeles' 'Beverly Hills' 'Huntington Park' ... 'Standish' 'Tulelake'
#  'Olympic Valley']
#
# Zip Code : [90003 90005 90006 ... 96128 96134 96146]
#
# Latitude : [33.964131 34.059281 34.048013 ... 40.346634 41.813521 39.191797]
#
# Longitude : [-118.272783 -118.30742  -118.293953 ... -120.386422 -121.492666
#  -120.212401]
#
# Gender : ['Male' 'Female']
#
# Senior Citizen : ['No' 'Yes']
#
# Partner : ['No' 'Yes']
#
# Dependents : ['No' 'Yes']
#
# Tenure Months : [ 2  8 28 49 10  1 47 17  5 34 11 15 18  9  7 12 25 68 55 37  3 27 20  4
#  58 53 13  6 19 59 16 52 24 32 38 54 43 63 21 69 22 61 60 48 40 23 39 35
#  56 65 33 30 45 46 62 70 50 44 71 26 14 41 66 64 29 42 67 51 31 57 36 72
#   0]
#
# Phone Service : ['Yes' 'No']
#
# Multiple Lines : ['No' 'Yes' 'No phone service']
#
# Internet Service : ['DSL' 'Fiber optic' 'No']
#
# ...

# %%
# replacing function used to replace values with binary digits
data.replace(['Male', 'Yes', 'Female', 'No', 'No phone service', 'No internet service'], [1,1,0,0,0,0], inplace = True)
data.head(10).T
# Out:
#                                               0                 1  \
# CustomerID                           3668-QPYBK        9237-HQITU
# City                                Los Angeles       Los Angeles
# Zip Code                                  90003             90005
# Latitude                              33.964131         34.059281
# Longitude                           -118.272783        -118.30742
# Gender                                        1                 0
# Senior Citizen                                0                 0
# Partner                                       0                 0
# Dependents                                    0                 1
# Tenure Months                                 2                 2
# Phone Service                                 1                 1
# Multiple Lines                                0                 0
# Internet Service                            DSL       Fiber optic
# ...

# %% [markdown]
# * Binary columns of dataset are converted into 0 and 1.

# %% [markdown]
# ### **Please examine the distribution of monthly charges between males and females using box plots. Please explain the results also.**

# %%
# dataframe with Gender and Monthly Charges columns
# replacing labels 0 & 1 as Female and Male
df_monthly_charges = pd.DataFrame(data = data, columns = ['Gender', 'Monthly Charges'])
df_monthly_charges.replace([0,1],['Female', 'Male'], inplace=True)
print(df_monthly_charges)

# creating boxplot of Gender on X axis and Monthly Charges on Y axis with a title
sns.boxplot(x='Gender', y='Monthly Charges', data = df_monthly_charges).set_title('Monthly Charges between Males and Females')
# Out:
#       Gender  Monthly Charges
# 0       Male            53.85
# 1     Female            70.70
# 2     Female            99.65
# 3     Female           104.80
# 4       Male           103.70
# ...      ...              ...
# 7038  Female            21.15
# 7039    Male            84.80
# 7040  Female           103.20
# 7041  Female            29.60
# 7042    Male           105.65
#
# [7043 rows x 2 columns]
# Text(0.5, 1.0, 'Monthly Charges between Males and Females')

# %% [markdown]
# * From the above boxplot, is can be seen that min, max, median and other values of monthly charges are almost same for Male and Female. It is also evident from the below statistical summary results.
# * Monthly Charges for both Male and Female are almost same.

# %%
# to find out distinct gender summary (Male), filterting Male data
Male_Monthly_Charges = df_monthly_charges[df_monthly_charges.Gender == 'Male']
print(Male_Monthly_Charges['Monthly Charges'].describe())
# Out:
# count    3555.000000
# mean       64.327482
# std        30.116093
# min        18.250000
# 25%        35.225000
# 50%        70.100000
# 75%        89.875000
# max       118.350000
# Name: Monthly Charges, dtype: float64

# %%
# to find out distinct gender summary (Female), filterting Female data
Female_Monthly_Charges = df_monthly_charges[df_monthly_charges.Gender == 'Female']
print(Female_Monthly_Charges['Monthly Charges'].describe())
# Out:
# count    3488.000000
# mean       65.204243
# std        30.061341
# min        18.400000
# 25%        35.900000
# 50%        70.650000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
df_monthly_charges.groupby('Gender').describe()
# Out:
#        Monthly Charges                                                      \
#                  count       mean        std    min     25%    50%     75%
# Gender
# Female          3488.0  65.204243  30.061341  18.40  35.900  70.65  89.850
# Male            3555.0  64.327482  30.116093  18.25  35.225  70.10  89.875
#
#
#            max
# Gender
# Female  118.75
# Male    118.35

# %% [markdown]
# ### **Please find what is the minimum total charges for Los Angeles city. Please find which zip code has the maximum total charges.**

# %%
# creating a dataframe with ID, City, Zip Code and Total Charges
# converting Total charges to numerical values
# filtering Los Angeles city data and finding out min Total Charges of that city
df_total_charges = pd.DataFrame(data = data, columns = ['CustomerID','City', 'Zip Code', 'Total Charges'])
df_total_charges['Total Charges'] = pd.to_numeric(df_total_charges['Total Charges'], errors='coerce')
print('\nMinimum Total Charges for Los Angeles City : ', df_total_charges[df_total_charges['City']=='Los Angeles']['Total Charges'].min())
# Out:
# Minimum Total Charges for Los Angeles City :  18.8

# %% [markdown]
# * Minimum Total Charges for Los Angeles City is 18.8

# %%
# finding max() of Total Charges Column and subsetting the entire row of it
df_total_charges[df_total_charges['Total Charges']==df_total_charges['Total Charges'].max()]
# Out:
#       CustomerID           City  Zip Code  Total Charges
# 1206  2889-FPWRM  Mckinleyville     95519         8684.8

# %% [markdown]
# * Zip Code 95519 belongs to Mckinleyville city has the maximum Total Charges of 8684.8

# %% [markdown]
# ### **Please find which payment method has the highest churn score and which has the lowest churn score.**

# %% [markdown]
# * Since there are various payment methods and we were asked to find out both highest and lowest churn score we will plot a boxplot to find out which payment method has highest and lowest churn score.

# %%
# setting figure size
# plotting boxplot with Payment Method on X axis and Churn Score on Y axis with a title
plt.figure(figsize = (10,6))
sns.boxplot(x=data['Payment Method'], y=data['Churn Score'], data = data).set_title('Churn Score by Payment Method')
sns.set_palette("bright")

# %% [markdown]
# * Credit card (automatic) payment method among all methods has the lowest churn score and on the contrast all the payment methods have highest churn score of 100. However, Electronic check payment method has highest average churn score among all methods.

# %% [markdown]
# ### **Please create an appropriate plot to check the count of payment methods and explain it.**

# %% [markdown]
# * To find out count of payment methods, countplot is an appropriate plot here.
# * Using value_count() also we can find out count of each distinct payment method.

# %%
# counting each distinct payment methods and printing 
print(data['Payment Method'].value_counts())
# setting figure size and bright palette for better viewing
plt.figure(figsize = (10,6))
sns.set_palette("bright")

# creating countplot for payment methods
sns.countplot(x='Payment Method', data=data).set_title('Count of Payment Methods')
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: Payment Method, dtype: int64
# Text(0.5, 1.0, 'Count of Payment Methods')

# %% [markdown]
# ### **Please create an appropriate plot to see the relationship between monthly charges and total charges.**

# %% [markdown]
# * As the both variables are of numerical data types, scatterplot will be an appropriate plot to see the relationship between them.

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x=data['Monthly Charges'], y=data['Total Charges'])

# %%
plt.figure(figsize = (10,6))
sns.regplot(x=data['Monthly Charges'], y=data['Total Charges'])
# Out:
# <AxesSubplot:xlabel='Monthly Charges', ylabel='Total Charges'>

# %% [markdown]
# * Monthly Charges and Total Charges are having a positive linear relationship between them. As monthly charges increases, total charges will also increases and as monthly charges decreases, total charges will also decreases.

# %% [markdown]
# ### **Conclusions :**

# %% [markdown]
# ✈ Percentage of Females Users is **49.52%** which is only just 0.96% less than the Male Users (**50.48%**).
#
# ✈ Percentage of Senior Citizen Users is just only **16.21%** which far less than Non Senior Citizen Users (**83.79%**)
#
# ✈ Monthly Charges for both Male and Female are almost same.
#
# ✈ **Mckinleyville** city has the **maximum Total Charges** of **8684.8**.
#
# ✈ **Credit card (automatic)** payment method has the **lowest churn score** among all methods and on the contrast all the payment methods have highest churn score of 100. However, **Electronic check** payment method has **highest average churn score** among all methods.
#
# ✈ Monthly Charges and Total Charges are having a **positive linear relationship** between them. As monthly charges increases, total charges will also increases and as monthly charges decreases, total charges will also decreases. And also for a given monthly charges the total charges are also increasing.
